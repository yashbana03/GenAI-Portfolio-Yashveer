# %%
import streamlit as st 
import pandas as pd 
dict = { 
        "name": ["harry", "rohan" , "skill", "shubh"],
        "marks":[30,90,56,89],
        "city":["rampur", "kolkatta", "bareily", "kota"]
        }

# %%
df = pd.DataFrame(dict)
df
# Out:
#     name  marks      city
# 0  harry     30    rampur
# 1  rohan     90  kolkatta
# 2  skill     56   bareily
# 3  shubh     89      kota

# %%
df.to_csv("freinds_noIndex.csv", index=False)

# %%
df.head(2)
# Out:
#     name  marks      city
# 0  harry     30    rampur
# 1  rohan     90  kolkatta

# %%
df.tail(2)
# Out:
#     name  marks     city
# 2  skill     56  bareily
# 3  shubh     89     kota

# %%
df.describe()
# Out:
#            marks
# count   4.000000
# mean   66.250000
# std    28.871843
# min    30.000000
# 25%    49.500000
# 50%    72.500000
# 75%    89.250000
# max    90.000000

# %%
yash =  pd.read_csv("people.csv")

# %%
yash.head(5)
# Out:
#    Index          User Id First Name Last Name     Sex  \
# 0      1  88F7B33d2bcf9f5     Shelby   Terrell    Male
# 1      2  f90cD3E76f1A9b9    Phillip   Summers  Female
# 2      3  DbeAb8CcdfeFC2c   Kristine    Travis    Male
# 3      4  A31Bee3c201ef58    Yesenia  Martinez    Male
# 4      5  1bA7A3dc874da3c       Lori      Todd    Male
#
#                         Email                   Phone Date of birth  \
# 0        elijah57@example.net  001-084-906-7849x73518    1945-10-26
# 1       bethany14@example.com       214.112.6044x4913    1910-03-24
# 2       bthompson@example.com            277.609.7938    1992-07-02
# 3   kaitlinkaiser@example.com            584.094.6111    2017-08-03
# 4  buchananmanuel@example.net       689-207-3558x7233    1938-12-01
#
#             Job Title
# 0     Games developer
# 1      Phytotherapist
# 2           Homeopath
# 3   Market researcher
# 4  Veterinary surgeon

# %%
yash["First Name"][2] = " yashber"
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_30704\1641258485.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   yash["First Name"][2] = " yashber"
# ...

# %%
aa=yash.head(5)

# %%
yash.to_csv("people.csv")

# %%
aa
# Out:
#    Index          User Id First Name Last Name     Sex  \
# 0      1  88F7B33d2bcf9f5     Shelby   Terrell    Male
# 1      2  f90cD3E76f1A9b9    Phillip   Summers  Female
# 2      3  DbeAb8CcdfeFC2c    yashber    Travis    Male
# 3      4  A31Bee3c201ef58    Yesenia  Martinez    Male
# 4      5  1bA7A3dc874da3c       Lori      Todd    Male
#
#                         Email                   Phone Date of birth  \
# 0        elijah57@example.net  001-084-906-7849x73518    1945-10-26
# 1       bethany14@example.com       214.112.6044x4913    1910-03-24
# 2       bthompson@example.com            277.609.7938    1992-07-02
# 3   kaitlinkaiser@example.com            584.094.6111    2017-08-03
# 4  buchananmanuel@example.net       689-207-3558x7233    1938-12-01
#
#             Job Title
# 0     Games developer
# 1      Phytotherapist
# 2           Homeopath
# 3   Market researcher
# 4  Veterinary surgeon

# %%
aa.index = [1,2,3,4,5]

# %%
aa
# Out:
#    Index          User Id First Name Last Name     Sex  \
# 1      1  88F7B33d2bcf9f5     Shelby   Terrell    Male
# 2      2  f90cD3E76f1A9b9    Phillip   Summers  Female
# 3      3  DbeAb8CcdfeFC2c    yashber    Travis    Male
# 4      4  A31Bee3c201ef58    Yesenia  Martinez    Male
# 5      5  1bA7A3dc874da3c       Lori      Todd    Male
#
#                         Email                   Phone Date of birth  \
# 1        elijah57@example.net  001-084-906-7849x73518    1945-10-26
# 2       bethany14@example.com       214.112.6044x4913    1910-03-24
# 3       bthompson@example.com            277.609.7938    1992-07-02
# 4   kaitlinkaiser@example.com            584.094.6111    2017-08-03
# 5  buchananmanuel@example.net       689-207-3558x7233    1938-12-01
#
#             Job Title
# 1     Games developer
# 2      Phytotherapist
# 3           Homeopath
# 4   Market researcher
# 5  Veterinary surgeon
