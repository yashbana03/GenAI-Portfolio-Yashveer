# %%
import pandas as pd
data = pd.read_excel("GENAIroadmap.xlsx")
data
# Out:
#            Section                                              Topic  \
# 0    Python Basics   Introduction - What We will Learn In This Course
# 1    Python Basics                                   Course Materials
# 2    Python Basics                       Getting Started With VS Code
# 3    Python Basics      Different Ways Of Creating Python Environment
# 4    Python Basics                   Solve-Conda Not Recognized Issue
# ..             ...                                                ...
# 220  Generative AI                                Introduction To MCP
# 221  Generative AI                        Important Components Of MCP
# 222  Generative AI                   Communication Between Components
# 223  Generative AI                    Demo Of MCP With Claude Desktop
# 224  Generative AI  Build Me a Personalized AI Tutor Using LangCha...
#
#     Completed revision Confidence (1-5) Study Date Hours Spent  Notes
# ...

# %%
data.iloc[0,0]
# Out:
# '36-37'

# %%
import pandas as pd
data1 = pd.read_excel("GENAIroadmap.xlsx" , sheet_name = "resource") 
data1 =data1.head()
data1
# Out:
#         35                    Operator Overloading  \
# 0    36-37               Streamlit Basics & ML App
# 1    38-61     NLP Core (Tokenization to Word2Vec)
# 2    62-93           Deep Learning, RNN, LSTM, GRU
# 3   94-110      Transformers & Attention Mechanism
# 4  111-140  GenAI, LangChain Ecosystem, Embeddings
#
#                Python OOPs Playlist (Dunder Methods)  \
# 0                 Streamlit Tutorials & Crash Course
# 1  Natural Language Processing Playlist / CampusX...
# 2                Deep Learning Playlist (PyTorch/TF)
# 3     Let's build GPT from scratch / Neural Networks
# 4               Complete Generative AI Playlist 2026
#
#           Corey Schafer (YouTube)
# 0        Data Professor (YouTube)
# 1  Krish Naik / CampusX (YouTube)
# 2    Aladdin Persson / Krish Naik
# 3   Andrej Karpathy / 3Blue1Brown
# 4            Krish Naik (YouTube)

# %%
data1.iloc[1]
data1.iloc[0]
# Out:
# 35                                                                    36-37
# Operator Overloading                              Streamlit Basics & ML App
# Python OOPs Playlist (Dunder Methods)    Streamlit Tutorials & Crash Course
# Corey Schafer (YouTube)                            Data Professor (YouTube)
# Name: 0, dtype: object

# %%
data1["Operator Overloading"]
# Out:
# 0                 Streamlit Basics & ML App
# 1       NLP Core (Tokenization to Word2Vec)
# 2             Deep Learning, RNN, LSTM, GRU
# 3        Transformers & Attention Mechanism
# 4    GenAI, LangChain Ecosystem, Embeddings
# Name: Operator Overloading, dtype: object

# %%
data1[[35, "Operator Overloading"]]
# Out:
#         35                    Operator Overloading
# 0    36-37               Streamlit Basics & ML App
# 1    38-61     NLP Core (Tokenization to Word2Vec)
# 2    62-93           Deep Learning, RNN, LSTM, GRU
# 3   94-110      Transformers & Attention Mechanism
# 4  111-140  GenAI, LangChain Ecosystem, Embeddings

# %%
data1[0:2]
# Out:
#       35                 Operator Overloading  \
# 0  36-37            Streamlit Basics & ML App
# 1  38-61  NLP Core (Tokenization to Word2Vec)
#
#                Python OOPs Playlist (Dunder Methods)  \
# 0                 Streamlit Tutorials & Crash Course
# 1  Natural Language Processing Playlist / CampusX...
#
#           Corey Schafer (YouTube)
# 0        Data Professor (YouTube)
# 1  Krish Naik / CampusX (YouTube)

# %%
data1
# Out:
#         35                    Operator Overloading  \
# 0    36-37               Streamlit Basics & ML App
# 1    38-61     NLP Core (Tokenization to Word2Vec)
# 2    62-93           Deep Learning, RNN, LSTM, GRU
# 3   94-110      Transformers & Attention Mechanism
# 4  111-140  GenAI, LangChain Ecosystem, Embeddings
#
#                Python OOPs Playlist (Dunder Methods)  \
# 0                 Streamlit Tutorials & Crash Course
# 1  Natural Language Processing Playlist / CampusX...
# 2                Deep Learning Playlist (PyTorch/TF)
# 3     Let's build GPT from scratch / Neural Networks
# 4               Complete Generative AI Playlist 2026
#
#           Corey Schafer (YouTube)
# 0        Data Professor (YouTube)
# 1  Krish Naik / CampusX (YouTube)
# 2    Aladdin Persson / Krish Naik
# 3   Andrej Karpathy / 3Blue1Brown
# 4            Krish Naik (YouTube)

# %%
data1.iloc[1]
# Out:
# 35                                                                                   38-61
# Operator Overloading                                   NLP Core (Tokenization to Word2Vec)
# Python OOPs Playlist (Dunder Methods)    Natural Language Processing Playlist / CampusX...
# Corey Schafer (YouTube)                                     Krish Naik / CampusX (YouTube)
# Name: 1, dtype: object

# %%
data1["Operator Overloading"][1]
# Out:
# 'NLP Core (Tokenization to Word2Vec)'

# %%
data1[1]["Operator Overloading"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Lenovo\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[120], line 1
# ----> 1 data1[1]["Operator Overloading"]
#
# ...

# %%
data1[1:2][["Operator Overloading" , "Python OOPs Playlist (Dunder Methods)"]]
# Out:
#                   Operator Overloading  \
# 1  NLP Core (Tokenization to Word2Vec)
#
#                Python OOPs Playlist (Dunder Methods)
# 1  Natural Language Processing Playlist / CampusX...

# %%
data1.iloc[0]
# Out:
# 35                                                                    36-37
# Operator Overloading                              Streamlit Basics & ML App
# Python OOPs Playlist (Dunder Methods)    Streamlit Tutorials & Crash Course
# Corey Schafer (YouTube)                            Data Professor (YouTube)
# Name: 0, dtype: object

# %%
data1.iloc[:,0]
# Out:
# 0      36-37
# 1      38-61
# 2      62-93
# 3     94-110
# 4    111-140
# Name: 35, dtype: object

# %%
data1.iloc[0,3]
# Out:
# 'Data Professor (YouTube)'
