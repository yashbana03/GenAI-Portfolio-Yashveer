# %%
class Cat : 
    def voice(self):
        return ("meowwwwww")
    
class Frog :
    def voice(self): 
        return ("gtrrrrr")

class Dog : 
    def voice(self):
    
        return ("woff woff")
    
def animal_sound(animal):
    print(animal.voice())
    
e1 =  Dog()
animal_sound(e1)
# Out:
# woff woff

# %%
# code desciption 
class Twitter:
   def __init__(self, content):
       self.content = content

   def post(self):
       return f"🐦 Tweet: '{self.content}' (280 chars max)"

class Instagram:
   def __init__(self, content):
       self.content = content

   def post(self):
       return f"📸 Instagram Post: '{self.content}' + ✨ filters"

class LinkedIn:
   def __init__(self, content):
       self.content = content

   def post(self):
       return f"💼 LinkedIn Article: '{self.content}' (Professional Mode)"

def start(social_media):
   print(social_media.post())  
   

photo = (Instagram("Sunset vibes 🌅"))
start(photo)


tweet = Twitter('Just learned Python polymorphism!')
start(tweet)

article = LinkedIn('Why OOP matters in 2024')
start(article)
# Out:
# 📸 Instagram Post: 'Sunset vibes 🌅' + ✨ filters
# 🐦 Tweet: 'Just learned Python polymorphism!' (280 chars max)
# 💼 LinkedIn Article: 'Why OOP matters in 2024' (Professional Mode)

# %%
class Animal : 
    def voice(self):
        return("some sounds of animals")
class Dog(Animal):
    def voice(self):
        return ("woff woff")
class Monkey(Animal):
   def voice(self):
       return 'A monkey ooh ooh aah aah ooh ooh aah aah'
class Cat(Animal):
   def voice(self):
       return 'A cat meow'
   
print(Cat().voice())
print(Monkey().voice())
print(Dog().voice())
print(Animal().voice())
# Out:
# A cat meow
# A monkey ooh ooh aah aah ooh ooh aah aah
#  woff woff
# some sounds of animals

# %%
list_animals= [ Cat(), Dog(), Monkey()]
for i in list_animals:
    print(i.voice())
# Out:
# A cat meow
#  woff woff
# A monkey ooh ooh aah aah ooh ooh aah aah

# %%
class Example:
    def __init__(self):
        self._internal = 'I can be accessed from outside the class, but should not'
        self.__private = 'You cannot access me directly from outside the class'

obj = Example()

print(obj._internal) # I can be accessed from outside the class, but should not
print(obj.__private)
# Out:
# I can be accessed from outside the class, but should not
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 9
#       6 obj = Example()
#       8 print(obj._internal) # I can be accessed from outside the class, but should not
# ----> 9 print(obj.__private)
#
# AttributeError: 'Example' object has no attribute '__private'

# %%
class Example:
    def __init__(self, internal , private):
        self._internal = internal
        self.__private = private
        
e1 = Example(
    'I can be accessed from outside the class, but should not',
    'I cannot be accessed directly from outside the class' 
             )
print(e1.__dict__)
# Out:
# {'_internal': 'I can be accessed from outside the class, but should not', '_Example__private': 'I cannot be accessed directly from outside the class'}

# %%
print( e1._internal)
# Out:
# I can be accessed from outside the class, but should not

# %%
print ( e1._Example__private )
# Out:
# I cannot be accessed directly from outside the class

# %%
class Parent:
    def __init__(self):
         self.__data = "Parent data"
        
class Child (Parent):
    def __init__(self):
        super().__init__()
        self.__data = "Child data"
        
        
print(Child().__dict__  )
# Out:
# {'_Parent__data': 'Parent data', '_Child__data': 'Child data'}

# %%
class parent : 
    def __init__(self):
         self.data= "Parent data "

class Child (parent):
    def __init__(self):
        super().__init__()
        self.data = "Child data" 
        
print(Child().__dict__)
# Out:
# {'data': 'Child data'}
