# %%
mySTR="""helloe
aslkrnn
rggffg"""
print(mySTR)
# Out:
# helloe
# aslkrnn
# rggffg

# %%
str= "it's"
print(str)
# Out:
# it's

# %%
str= 'hello"world"'
print(str)
# Out:
# hello"world"

# %%
str = "he","world"
print(str)
# Out:
# ('he', 'world')
