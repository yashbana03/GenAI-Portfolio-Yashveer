# %%
class person:
    name = "yashveer"
    age = 20
    occupation = "airforce officer"
    def info (self):
        print(f"{self.name} is a {self.occupation}")
a = person()
#a.name= "gudiya"
#a.occupation = "software engineer"

a.info()
# Out:
# yashveer is a airforce officer

# %%
class person:
    name = "yashveer"
    age = 20
    occupation = "airforce officer"
    def info (self):
        print(f"{self.name} is a {self.occupation}")
a = person()
a.name= "gudiya"
a.occupation = "software engineer"

a.info()
# Out:
# gudiya is a software engineer

# %%
class person:
    name = " "
    age = int("88")
    occupation = " "
    def info (self):
        print(f"{self.name} is a {self.occupation}")
a = person()
a.name = "yashveer"
a.age=23
a.occupation = "software engineer"

b = person()
b.name= "gudiya"
b.occupation = "kuch nahi karna chahti"


a.info()
b.info()
# Out:
# yashveer is a software engineer
# gudiya is a kuch nahi karna chahti
