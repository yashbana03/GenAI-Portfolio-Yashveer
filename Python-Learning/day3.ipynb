# %%
my_int = "hello"

# %%
print("int:", my_int)
# Out:
# int: hello

# %%
MY_SET  = {1, "hello", 3.14}
print("set:", MY_SET)
# Out:
# set: {'hello', 3.14, 1}

# %%
my_dict= {"name": "Yashveer", "age": 20, "city": "kota"}

# %%
print("dict",my_dict)
# Out:
# dict {'name': 'Yashveer', 'age': 20, 'city': 'kota'}

# %%
my_tuple = (1, "hello", 3.14)
print("tuple:", my_tuple)
# Out:
# tuple: (1, 'hello', 3.14)

# %%
my_range= range(0,10)
print("range:", my_range)
# Out:
# range: range(0, 10)

# %%
my_list = [1, "hello", 3.14,23423,2,2]
print("list:", my_list)
# Out:
# list: [1, 'hello', 3.14, 23423, 2, 2]

# %%
print(type(MY_SET),type(my_dict),type(my_tuple),type(my_range),type(my_list))
# Out:
# <class 'set'> <class 'dict'> <class 'tuple'> <class 'range'> <class 'list'>

# %%
my_tuple = (1, "hello", 3.35614)
print("tuple:", my_tuple)
# Out:
# tuple: (1, 'hello', 3.35614)

# %%
print("yahseebr;lsj")
# Out:
# yahseebr;lsj

# %%
print("yah")
# Out:
# yah

# %%
isinstance(my_tuple, set)
# Out:
# False

# %%
isinstance(my_tuple, tuple)
# Out:
# True

# %%
a=isinstance("34324", str)
b=isinstance(34324, str)
print(a)
print(b)
# Out:
# True
# False
