# %%
str = "hello\""
print(str)
# Out:
# hello"

# %%
str = "i iam a" , "graduate student"
print("a" in str)
print(str)
# Out:
# False
# ('i iam a', 'graduate student')

# %%
str = "he"
print(len(str))
# Out:
# 2

# %%
str = "hesidfb"
print(str[0])
print(str[-2])
# Out:
# h
# f

# %%
greetings = "hello"
#greetings[0]="TY"

# %%
STR1 = "OHHHHH"
STR2 = "yeahhh"
result1 = STR1 +" "+ STR2  
result2 = STR1 + STR2
result2 += result1
print(result2)
# Out:
# OHHHHHyeahhhOHHHHH yeahhh

# %%
str1= "herlwke"
age = 3434
result = str1 + str(age)
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 3
#       1 str1= "herlwke"
#       2 age = 3434
# ----> 3 result = str1 + str(age)
#       4 print(result)
#
# TypeError: 'str' object is not callable

# %%
name = 'John Doe'
age = 26

name_and_age = name + str(age)
print(name_and_age)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 4
#       1 name = 'John Doe'
#       2 age = 26
# ----> 4 name_and_age = name + str(age)
#       5 print(name_and_age)
#
# TypeError: 'str' object is not callable
