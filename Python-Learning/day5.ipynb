# %%
str_1 = "hello\""
print(str_1)

# %%
str_23 = "i iam a" , "graduate student"
print("a" in str_23)
print(str_23)

# %%
TEXT = "he"
print(len(TEXT))

# %%
str_22 = "hesidfb"
print(str_22[0])
print(str_22[-2])

# %%
greetings = "hello"
#greetings[0]="TY"

# %%
STR_1 = "OHHHHH"
STR_2 = "yeahhh"
result1 = STR_1 +" "+ STR_2  
result2 = STR_1 + STR_2
result2 += result1
print(result2)

# %%
AGE = 23
print(str(AGE))
# Out:
# 23
