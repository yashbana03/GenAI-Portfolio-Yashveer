# %%
import math
math.sqrt
# Out:
# <function math.sqrt(x, /)>

# %%
import math as m 
m.sqrt(3434)
# Out:
# 58.60034129593445

# %%
import math as m 
m.sqrt(3434)
from math import sin , cos

# %%
from math import * # gets all the functions from math module
print(sqrt(36))  # 6.0
print(pow(5, 2)) # 25.0
print(exp(1))    # 2.718281828459045
# Out:
# 6.0
# 25.0
# 2.718281828459045

# %%
import math
print(math.pi)
# Out:
# 3.141592653589793

# %%
import datetime as dt 
birthday = dt.datetime(2003, 11, 25)
print(birthday)
# Out:
# 2003-11-25 00:00:00
