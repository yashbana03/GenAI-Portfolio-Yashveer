# %%
def number_pattern(n):
    string= ""
    if not isinstance(n, int):
        return("Argument must be an integer value.")
    if n < 1:
        return("Argument must be an integer greater than 0.")
    else :
        for i in range(1, n + 1):
            string +=( str(i) + " ")
    return string.rstrip()
            
print(number_pattern("sfg"))
# Out:
# Argument must be an integer value.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 12
#       9             string +=( str(i) + " ")
#      10     return string.rstrip()
# ---> 12 print(number_pattern("sfg"))
#
# Cell In[25], line 5, in number_pattern(n)
#       3 if not isinstance(n, int):
#       4     print("Argument must be an integer value.")
# ----> 5 if n < 1:
#       6     print("Argument must be an integer greater than 0.")
#       7 else :
#
# TypeError: '<' not supported between instances of 'str' and 'int'
