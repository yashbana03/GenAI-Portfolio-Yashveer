# %%
class Wallet:
   def __init__(self, balance):
       self._balance = balance # For internal use by convention

   def deposit(self, amount):
       if amount > 0:
           self._balance += amount # Add to the balance safely

   def withdraw(self, amount):
       if 0 < amount <= self._balance:
           self._balance -= amount # Remove from the balance safely
account = Wallet(500)
print(account._balance) # Accessing the balance directly (not recommended)
# Out:
# 500

# %%
class Wallet:
   def __init__(self, balance):
       self.__balance = balance # Private attribute

   def deposit(self, amount):
       if amount > 0:
           self.__balance += amount # Add to the balance safely

   def withdraw(self, amount):
       if 0 < amount <= self.__balance:
           self.__balance -= amount # Remove from the balance safely

account = Wallet(500)
print(account.__balance) # AttributeError: 'Wallet' object has no attribute '__balance'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 14
#      11            self.__balance -= amount # Remove from the balance safely
#      13 account = Wallet(500)
# ---> 14 print(account.__balance)
#
# AttributeError: 'Wallet' object has no attribute '__balance'

# %%
class Wallet:
   def __init__(self, balance):
       self.__balance = balance

   def deposit(self, amount):
       if amount > 0:
           self.__balance += amount

   def withdraw(self, amount):
       if 0 < amount <= self.__balance:
           self.__balance -= amount
  
   def get_balance(self):
       return self.__balance


acct_one = Wallet(100)
acct_one.deposit(50)
print(acct_one.get_balance()) # 150

acct_two = Wallet(450)
acct_two.withdraw(28)
print(acct_two.get_balance()) # 422

acct_two.deposit(150)
print(acct_two.get_balance()) # 572
# Out:
# 500

# %%
class Wallet:
    def __init__(self, balance):
        self.__balance = balance

account = Wallet(100)
print(account._Wallet__balance)  # 100 print ho jayega
# Out:
# 100

# %%
class Myclass :
    def __init__(self, value):
        self._value = value
    def show(self):
        print(f"Value: {self._value}")    
    @property
    def ten_value(self):
        return 10*self._value
    @ten_value.setter
    def ten_value(self, new_value):
        self._value = new_value/10
        
obj = Myclass(10)
obj.ten_value = 67 # setter method call hoga, _value me 10 store ho jayega
print(obj.ten_value) # 10 print ho jayega
obj.show() # Value: 10 print ho jayega
# Out:
# 67.0
# Value: 6.7

# %%
class Circle:
    def __init__(self, radius):
        self._radius = radius

    @property
    def radius(self): # A getter to get the radius
        return self._radius
  
    @property
    def area(self):  # A getter to calculate area
        return 3.14 * (self._radius ** 2)

my_circle = Circle(3)

print(my_circle.radius) # 3
print(my_circle.area) # 28.26
# Out:
# 3
# 28.26

# %%
class Circle:
    def __init__(self, radius):
        self.radius = radius # Calling the setter

    @property
    def radius(self):  # A getter to get the radius
        return self._radius

    @radius.setter
    def radius(self, value):  # A setter to set the radius
        if value <= 0:
            raise ValueError('Radius must be positive')
        self._radius = value

my_circle = Circle(3)
print('Initial radius:', my_circle.radius) # Initial radius: 3

my_circle.radius =4
print('After modifying the radius:', my_circle.radius) # After modifyi
# Out:
# Initial radius: 3
# After modifying the radius: 4
